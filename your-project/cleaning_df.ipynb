# %%
import pandas as pd

# %%
data = pd.read_csv('../datasets/3.-Population/2019_ine_nacionalitat_per_sexe.csv')

# %%
datacopy = data.copy()

# %%
data
# Out:
#         Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0      2019               1  Ciutat Vella           1
# 1      2019               1  Ciutat Vella           2
# 2      2019               1  Ciutat Vella           3
# 3      2019               1  Ciutat Vella           4
# 4      2019               2      Eixample           5
# ...     ...             ...           ...         ...
# 26275  2019              10    Sant Martí          69
# 26276  2019              10    Sant Martí          70
# 26277  2019              10    Sant Martí          71
# 26278  2019              10    Sant Martí          72
# 26279  2019              10    Sant Martí          73
#
#                                           Nom_Barri  Sexe Nacionalitat  Nombre
# 0                                          el Raval  Dona      Espanya   11666
# 1                                    el Barri Gòtic  Dona      Espanya    4214
# ...

# %%
data.head()
# Out:
#     Any  Codi_Districte Nom_Districte  Codi_Barri  \
# 0  2019               1  Ciutat Vella           1
# 1  2019               1  Ciutat Vella           2
# 2  2019               1  Ciutat Vella           3
# 3  2019               1  Ciutat Vella           4
# 4  2019               2      Eixample           5
#
#                                Nom_Barri  Sexe Nacionalitat  Nombre
# 0                               el Raval  Dona      Espanya   11666
# 1                         el Barri Gòtic  Dona      Espanya    4214
# 2                         la Barceloneta  Dona      Espanya    4801
# 3  Sant Pere, Santa Caterina i la Ribera  Dona      Espanya    6570
# 4                          el Fort Pienc  Dona      Espanya   13074

# %%
sorted_data = data.sort_values(by='Nom_Barri', axis=0, ascending=False)

# %%
sorted_data.head(50)
# Out:
#         Any  Codi_Districte        Nom_Districte  Codi_Barri        Nom_Barri  \
# 21266  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 24843  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 10535  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 6374   2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 12214  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 8564   2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 18492  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 13309  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 21047  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 15864  2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# 9805   2019               5  Sarrià-Sant Gervasi          24  les Tres Torres
# ...

# %%
data['Nom_Barri'].value_counts()
# Out:
# la Trinitat Nova                 360
# la Vila Olímpica del Poblenou    360
# el Raval                         360
# Can Baró                         360
# Canyelles                        360
#                                 ...
# el Fort Pienc                    360
# Torre Baró                       360
# Sant Gervasi - Galvany           360
# la Barceloneta                   360
# el Baix Guinardó                 360
# Name: Nom_Barri, Length: 73, dtype: int64

# %%
data.corr()
# Out:
#                 Any  Codi_Districte  Codi_Barri    Nombre
# Any             NaN             NaN         NaN       NaN
# Codi_Districte  NaN        1.000000    0.980874 -0.015829
# Codi_Barri      NaN        0.980874    1.000000 -0.014510
# Nombre          NaN       -0.015829   -0.014510  1.000000

# %%
data['Any'].dtype
# Out:
# dtype('int64')

# %%
melted = data.melt(id_vars=['Nom_Barri', 'Sexe', 'Nacionalitat'], value_vars=['Nombre'])

# %%
melted_sorted = melted.sort_values(by='Nom_Barri', axis=0, ascending=False)

# %%
melted_sorted.tail(20)
# Out:
#            Nom_Barri  Sexe                    Nacionalitat variable  value
# 22176  Baró de Viver  Home                        Barbados   Nombre      0
# 22030  Baró de Viver  Home               Trinitat i Tobago   Nombre      0
# 17796  Baró de Viver  Home                          Angola   Nombre      0
# 13270  Baró de Viver  Home                          Itàlia   Nombre      2
# 16628  Baró de Viver  Home                         Senegal   Nombre      1
# 5167   Baró de Viver  Dona                       Sudan, el   Nombre      0
# 25680  Baró de Viver  Home                         Bahrain   Nombre      0
# 10569  Baró de Viver  Dona                          Israel   Nombre      0
# 25972  Baró de Viver  Home            Altres països d'Àsia   Nombre      0
# 18818  Baró de Viver  Home                           Níger   Nombre      0
# 9182   Baró de Viver  Dona  Saint Vincent i les Grenadines   Nombre      0
# ...

# %%
data['Nom_Districte'].value_counts()
# Out:
# Nou Barris             4680
# Horta-Guinardó         3960
# Sant Martí             3600
# Sants-Montjuïc         2880
# Sant Andreu            2520
# Sarrià-Sant Gervasi    2160
# Eixample               2160
# Gràcia                 1800
# Ciutat Vella           1440
# Les Corts              1080
# Name: Nom_Districte, dtype: int64

# %%
data.columns.tolist()
# Out:
# ['Any',
#  'Codi_Districte',
#  'Nom_Districte',
#  'Codi_Barri',
#  'Nom_Barri',
#  'Sexe',
#  'Nacionalitat',
#  'Nombre']

# %%
data.columns = ['Year', 'District_Code', 'District_Name', 'Neighbor_Code', 'Neighbor_Name', 'Gender', 'Nationality', 'Residents_numb']

# %%
data.columns.tolist()
# Out:
# ['Year',
#  'District_Code',
#  'District_Name',
#  'Neighbor_Code',
#  'Neighbor_Name',
#  'Gender',
#  'Nationality',
#  'Residents_numb']

# %%
data_columns = data[data.columns]
data_columns
# Out:
#        Year  District_Code District_Name  Neighbor_Code  \
# 0      2019              1  Ciutat Vella              1
# 1      2019              1  Ciutat Vella              2
# 2      2019              1  Ciutat Vella              3
# 3      2019              1  Ciutat Vella              4
# 4      2019              2      Eixample              5
# ...     ...            ...           ...            ...
# 26275  2019             10    Sant Martí             69
# 26276  2019             10    Sant Martí             70
# 26277  2019             10    Sant Martí             71
# 26278  2019             10    Sant Martí             72
# 26279  2019             10    Sant Martí             73
#
#                                       Neighbor_Name Gender Nationality  \
# 0                                          el Raval   Dona     Espanya
# 1                                    el Barri Gòtic   Dona     Espanya
# 2                                    la Barceloneta   Dona     Espanya
# ...

# %%
data['Gender'] = data['Gender'].str.replace("Dona", "Female")

# %%
data['Gender'] = data['Gender'].str.replace("Home", "Male")

# %%
data.Nationality.unique()
# Out:
# array(['Espanya', 'Itàlia', 'França', 'Regne Unit', 'Rússia', 'Alemanya',
#        'Romania', 'Portugal', 'Ucraïna', 'Geòrgia', 'Països Baixos',
#        'Polònia', 'Bulgària', 'Suècia', 'Bèlgica', 'Grècia', 'Irlanda',
#        'Suïssa', 'Hongria', 'Àustria', 'Dinamarca', 'Finlàndia',
#        'Moldàvia', 'Lituània', 'Belarús', 'Txèquia', 'Sèrbia', 'Albània',
#        'Croàcia', 'Noruega', 'Eslovàquia', 'Andorra', 'Letònia',
#        'Estònia', 'Eslovènia', 'Macedònia', 'Islàndia',
#        'Bòsnia i Hercegovina', 'Luxemburg', 'Malta', 'Montenegro',
#        'Liechtenstein', 'Mònaco', 'San Marino', "Altres països d'Europa",
#        'Marroc, el', 'Algèria', 'Senegal', 'Nigèria', 'Egipte', 'Ghana',
#        'Guinea', 'Guinea Equatorial', 'Tunísia', 'Camerun', 'Gàmbia',
#        'Sud-àfrica', 'Mali', 'Líbia', 'Guinea-Bissau', "Costa d'Ivori",
#        'Kenya', 'Mauritània', 'Angola', 'Congo', 'Etiòpia',
#        'Burkina Faso', 'Tanzània', 'Sierra Leone', 'Moçambic',
# ...

# %%
data.Nationality.value_counts()
# Out:
# Equador                     146
# Sri Lanka                   146
# Israel                      146
# Surinam                     146
# Bahames, les                146
#                            ...
# Emirats Àrabs Units, els    146
# Hondures                    146
# Lituània                    146
# Noruega                     146
# Marroc, el                  146
# Name: Nationality, Length: 180, dtype: int64

# %%
data_pd_series = data.groupby('Nationality')['Residents_numb'].sum().nlargest(10)

# %%
data_pd_series
# Out:
# Nationality
# Espanya       1316380
# Itàlia          34287
# Xina            21327
# Pakistan        20437
# França          15757
# Marroc, el      14269
# Colòmbia        11796
# Hondures        11593
# Perú            10240
# Veneçuela       10012
# Name: Residents_numb, dtype: int64

# %%
nationalities_lst = ['Espanya', 'Itàlia', 'Xina', 'Pakistan', 'França', 'Marroc, el', 'Colòmbia', 'Hondures', 'Perú', 'Veneçuela']
eng_nationalities_lst = ['Spain', 'Italy', 'China', 'Pakistan', 'France', 'Morocco', 'Colombia', 'Honduras', 'Peru', 'Venezuela']

# %%
filtered_data = data[(data['Nationality']=='Espanya') |
                     (data['Nationality']=='Itàlia') |
                     (data['Nationality']=='Xina') |
                     (data['Nationality']=='Pakistan') |
                     (data['Nationality']=='França') |
                     (data['Nationality']=='Marroc, el') |
                     (data['Nationality']=='Colòmbia') |
                     (data['Nationality']=='Hondures') |
                     (data['Nationality']=='Perú') |
                     (data['Nationality']=='Veneçuela')                    
                     ]

filtered_data
# Out:
#        Year  District_Code District_Name  Neighbor_Code  \
# 0      2019              1  Ciutat Vella              1
# 1      2019              1  Ciutat Vella              2
# 2      2019              1  Ciutat Vella              3
# 3      2019              1  Ciutat Vella              4
# 4      2019              2      Eixample              5
# ...     ...            ...           ...            ...
# 22917  2019             10    Sant Martí             69
# 22918  2019             10    Sant Martí             70
# 22919  2019             10    Sant Martí             71
# 22920  2019             10    Sant Martí             72
# 22921  2019             10    Sant Martí             73
#
#                                       Neighbor_Name  Gender Nationality  \
# 0                                          el Raval  Female     Espanya
# 1                                    el Barri Gòtic  Female     Espanya
# 2                                    la Barceloneta  Female     Espanya
# ...

# %%
filtered_data.Nationality.value_counts()
# Out:
# França        146
# Colòmbia      146
# Pakistan      146
# Perú          146
# Itàlia        146
# Espanya       146
# Hondures      146
# Xina          146
# Veneçuela     146
# Marroc, el    146
# Name: Nationality, dtype: int64

# %%
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Colòmbia", "Colombia")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Pakistan", "Pakistan")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Xina", "China")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Hondures", "Honduras")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("França", "France")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Itàlia", "Italy")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Veneçuela", "Venezuela")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Espanya", "Spain")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Marroc, el", "Morocco")
filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Perú", "Peru")
# Out:
# <ipython-input-28-b4c6e14ca369>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Colòmbia", "Colombia")
# <ipython-input-28-b4c6e14ca369>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Nationality'] = filtered_data['Nationality'].str.replace("Pakistan", "Pakistan")
# <ipython-input-28-b4c6e14ca369>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
filtered_data.Nationality.value_counts()
# Out:
# Venezuela    146
# Peru         146
# France       146
# Pakistan     146
# Spain        146
# Honduras     146
# Italy        146
# China        146
# Colombia     146
# Morocco      146
# Name: Nationality, dtype: int64

# %%
filtered_data2 = filtered_data.drop(axis=1, labels=['District_Code', 'Year', 'Neighbor_Code'])

# %%
filtered_data2
# Out:
#       District_Name                                 Neighbor_Name  Gender  \
# 0      Ciutat Vella                                      el Raval  Female
# 1      Ciutat Vella                                el Barri Gòtic  Female
# 2      Ciutat Vella                                la Barceloneta  Female
# 3      Ciutat Vella         Sant Pere, Santa Caterina i la Ribera  Female
# 4          Eixample                                 el Fort Pienc  Female
# ...             ...                                           ...     ...
# 22917    Sant Martí  Diagonal Mar i el Front Marítim del Poblenou    Male
# 22918    Sant Martí                         el Besòs i el Maresme    Male
# 22919    Sant Martí                       Provençals del Poblenou    Male
# 22920    Sant Martí                      Sant Martí de Provençals    Male
# 22921    Sant Martí                           la Verneda i la Pau    Male
#
#       Nationality  Residents_numb
# 0           Spain           11666
# ...
